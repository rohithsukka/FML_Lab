# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("onlinefoods[1].csv")

# %%
df
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         388 non-null    int64
#  1   Gender                      388 non-null    object
#  2   Marital Status              388 non-null    object
#  3   Occupation                  388 non-null    object
#  4   Monthly Income              388 non-null    object
#  5   Educational Qualifications  388 non-null    object
#  6   Family size                 388 non-null    int64
#  7   latitude                    388 non-null    float64
#  8   longitude                   388 non-null    float64
#  9   Pin code                    388 non-null    int64
#  10  Output                      388 non-null    object
#  11  Feedback                    388 non-null    object
#  12  Unnamed: 12                 388 non-null    object
# ...

# %%
d=np.array(df)
d
# Out:
# array([[20, 'Female', 'Single', ..., 'Yes', 'Positive', 'Yes'],
#        [24, 'Female', 'Single', ..., 'Yes', 'Positive', 'Yes'],
#        [22, 'Male', 'Single', ..., 'Yes', 'Negative ', 'Yes'],
#        ...,
#        [22, 'Female', 'Single', ..., 'Yes', 'Positive', 'Yes'],
#        [23, 'Male', 'Single', ..., 'Yes', 'Positive', 'Yes'],
#        [23, 'Male', 'Single', ..., 'Yes', 'Positive', 'Yes']],
#       dtype=object)

# %%
df.shape
# Out:
# (388, 13)

# %%
df
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
df1 = df[['Gender','Marital Status','Occupation','Monthly Income','Educational Qualifications','Family size','Output','Feedback']]
df1
# Out:
#      Gender Marital Status Occupation  Monthly Income  \
# 0    Female         Single    Student       No Income
# 1    Female         Single    Student  Below Rs.10000
# 2      Male         Single    Student  Below Rs.10000
# 3    Female         Single    Student       No Income
# 4      Male         Single    Student  Below Rs.10000
# ..      ...            ...        ...             ...
# 383  Female         Single    Student       No Income
# 384  Female         Single    Student       No Income
# 385  Female         Single    Student       No Income
# 386    Male         Single    Student  Below Rs.10000
# 387    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size Output   Feedback
# 0                Post Graduate            4    Yes   Positive
# 1                     Graduate            3    Yes   Positive
# 2                Post Graduate            3    Yes  Negative
# 3                     Graduate            6    Yes   Positive
# ...

# %%
df1=df1[:11]
df1
# Out:
#     Gender Marital Status Occupation   Monthly Income  \
# 0   Female         Single    Student        No Income
# 1   Female         Single    Student   Below Rs.10000
# 2     Male         Single    Student   Below Rs.10000
# 3   Female         Single    Student        No Income
# 4     Male         Single    Student   Below Rs.10000
# 5   Female        Married   Employee  More than 50000
# 6     Male         Single    Student        No Income
# 7   Female         Single    Student        No Income
# 8   Female         Single    Student        No Income
# 9   Female         Single    Student        No Income
# 10  Female         Single    Student        No Income
#
#    Educational Qualifications  Family size Output   Feedback
# 0               Post Graduate            4    Yes   Positive
# 1                    Graduate            3    Yes   Positive
# 2               Post Graduate            3    Yes  Negative
# 3                    Graduate            6    Yes   Positive
# ...

# %%
d2=df[df['Occupation']=='Student']
d2
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
d2=d2[:10]
d2
# Out:
#     Age  Gender Marital Status Occupation  Monthly Income  \
# 0    20  Female         Single    Student       No Income
# 1    24  Female         Single    Student  Below Rs.10000
# 2    22    Male         Single    Student  Below Rs.10000
# 3    22  Female         Single    Student       No Income
# 4    22    Male         Single    Student  Below Rs.10000
# 6    22    Male         Single    Student       No Income
# 7    24  Female         Single    Student       No Income
# 8    23  Female         Single    Student       No Income
# 9    23  Female         Single    Student       No Income
# 10   22  Female         Single    Student       No Income
#
#    Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0               Post Graduate            4   12.9766    77.5993    560001
# 1                    Graduate            3   12.9770    77.5773    560009
# 2               Post Graduate            3   12.9551    77.6593    560017
# ...

# %%
d2=d2[['Gender','Marital Status','Occupation','Monthly Income','Educational Qualifications','Family size','Output','Feedback']]

# %%
d2
# Out:
#     Gender Marital Status Occupation  Monthly Income  \
# 0   Female         Single    Student       No Income
# 1   Female         Single    Student  Below Rs.10000
# 2     Male         Single    Student  Below Rs.10000
# 3   Female         Single    Student       No Income
# 4     Male         Single    Student  Below Rs.10000
# 6     Male         Single    Student       No Income
# 7   Female         Single    Student       No Income
# 8   Female         Single    Student       No Income
# 9   Female         Single    Student       No Income
# 10  Female         Single    Student       No Income
#
#    Educational Qualifications  Family size Output   Feedback
# 0               Post Graduate            4    Yes   Positive
# 1                    Graduate            3    Yes   Positive
# 2               Post Graduate            3    Yes  Negative
# 3                    Graduate            6    Yes   Positive
# 4               Post Graduate            4    Yes   Positive
# ...

# %%
d=np.array(df1)
d
# Out:
# array([['Female', 'Single', 'Student', 'No Income', 'Post Graduate', 4,
#         'Yes', 'Positive'],
#        ['Female', 'Single', 'Student', 'Below Rs.10000', 'Graduate', 3,
#         'Yes', 'Positive'],
#        ['Male', 'Single', 'Student', 'Below Rs.10000', 'Post Graduate',
#         3, 'Yes', 'Negative '],
#        ['Female', 'Single', 'Student', 'No Income', 'Graduate', 6, 'Yes',
#         'Positive'],
#        ['Male', 'Single', 'Student', 'Below Rs.10000', 'Post Graduate',
#         4, 'Yes', 'Positive'],
#        ['Female', 'Married', 'Employee', 'More than 50000',
#         'Post Graduate', 2, 'Yes', 'Positive'],
#        ['Male', 'Single', 'Student', 'No Income', 'Graduate', 3, 'Yes',
#         'Positive'],
#        ['Female', 'Single', 'Student', 'No Income', 'Post Graduate', 3,
#         'Yes', 'Positive'],
#        ['Female', 'Single', 'Student', 'No Income', 'Post Graduate', 2,
#         'Yes', 'Positive'],
# ...

# %%
t=df1[['Occupation']]
t
# Out:
#    Occupation
# 0     Student
# 1     Student
# 2     Student
# 3     Student
# 4     Student
# 5    Employee
# 6     Student
# 7     Student
# 8     Student
# 9     Student
# 10    Student

# %%
target=np.array(t)
target
# Out:
# array([['Student'],
#        ['Student'],
#        ['Student'],
#        ['Student'],
#        ['Student'],
#        ['Employee'],
#        ['Student'],
#        ['Student'],
#        ['Student'],
#        ['Student'],
#        ['Student']], dtype=object)

# %%
hypothesis=d2.iloc[0].tolist()
hypothesis
# Out:
# ['Female',
#  'Single',
#  'Student',
#  'No Income',
#  'Post Graduate',
#  4,
#  'Yes',
#  'Positive']

# %%
for i,row in df1.iterrows():
    if hypothesis != ['?', '?', '?', '?', '?']:
        for i, attr in enumerate(['Gender','Marital Status','Occupation','Monthly Income','Educational Qualifications','Family size','Output','Feedback']):
            if row[attr] != hypothesis[i]:
                hypothesis[i] = "?"
        print(hypothesis)
    else:
        break
# Out:
# ['Female', 'Single', 'Student', 'No Income', 'Post Graduate', 4, 'Yes', 'Positive']
# ['Female', 'Single', 'Student', '?', '?', '?', 'Yes', 'Positive']
# ['?', 'Single', 'Student', '?', '?', '?', 'Yes', '?']
# ['?', 'Single', 'Student', '?', '?', '?', 'Yes', '?']
# ['?', 'Single', 'Student', '?', '?', '?', 'Yes', '?']
# ['?', '?', '?', '?', '?', '?', 'Yes', '?']
# ['?', '?', '?', '?', '?', '?', 'Yes', '?']
# ['?', '?', '?', '?', '?', '?', 'Yes', '?']
# ['?', '?', '?', '?', '?', '?', 'Yes', '?']
# ['?', '?', '?', '?', '?', '?', 'Yes', '?']
# ['?', '?', '?', '?', '?', '?', 'Yes', '?']

# %%
df1.to_csv("output.csv", index=False)
